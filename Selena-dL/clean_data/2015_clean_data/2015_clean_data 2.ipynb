# %%
#Importing packages
import pandas as pd
import os
import numpy as np

# %%
#Loading test CSV: good
file_to_load = ("2015-co-sfbay-test.csv")
co_2015 =pd.read_csv(file_to_load)
co_2015.head()
# Out:
#       test       csv
# 0  testing  new_file

# %%
#Loading raw data CSV: 2015 Carbon Monoxide (CO)
file_to_load = ("2015-co-sfbay.csv")
CO_2015 =pd.read_csv(file_to_load)
CO_2015.head()
# Out:
#          Date Source   Site ID  POC  Daily Max 8-hour CO Concentration UNITS  \
# 0  01/01/2015    AQS  60010009    1                                0.5   ppm
# 1  01/02/2015    AQS  60010009    1                                0.6   ppm
# 2  01/03/2015    AQS  60010009    1                                0.8   ppm
# 3  01/04/2015    AQS  60010009    1                                0.8   ppm
# 4  01/05/2015    AQS  60010009    1                                1.0   ppm
#
#    DAILY_AQI_VALUE Site Name  DAILY_OBS_COUNT  PERCENT_COMPLETE  \
# 0                6   Oakland               18              75.0
# 1                7   Oakland               24             100.0
# 2                9   Oakland               24             100.0
# 3                9   Oakland               24             100.0
# 4               11   Oakland               24             100.0
#
#    AQS_PARAMETER_CODE AQS_PARAMETER_DESC  CBSA_CODE  \
# 0               42101    Carbon monoxide      41860
# ...

# %%
#Checking Columns
CO_2015.columns
# Out:
# Index(['Date', 'Source', 'Site ID', 'POC', 'Daily Max 8-hour CO Concentration',
#        'UNITS', 'DAILY_AQI_VALUE', 'Site Name', 'DAILY_OBS_COUNT',
#        'PERCENT_COMPLETE', 'AQS_PARAMETER_CODE', 'AQS_PARAMETER_DESC',
#        'CBSA_CODE', 'CBSA_NAME', 'STATE_CODE', 'STATE', 'COUNTY_CODE',
#        'COUNTY', 'SITE_LATITUDE', 'SITE_LONGITUDE'],
#       dtype='object')

# %%
#Checking Null Values
CO_2015.columns.isnull()
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False])

# %%
#Dropping Columns
CO_2015 = CO_2015.drop(columns=['Source','Site ID','POC','DAILY_OBS_COUNT','PERCENT_COMPLETE','AQS_PARAMETER_CODE','AQS_PARAMETER_DESC', 'CBSA_CODE','CBSA_NAME','STATE_CODE','STATE','COUNTY_CODE','SITE_LATITUDE', 'SITE_LONGITUDE'], axis=1)

# %%
#Checking Columns after drop
CO_2015.columns
# Out:
# Index(['Date', 'Daily Max 8-hour CO Concentration', 'UNITS', 'DAILY_AQI_VALUE',
#        'Site Name', 'COUNTY'],
#       dtype='object')

# %%
#Checking DataFrame
CO_2015.head()
# Out:
#          Date  Daily Max 8-hour CO Concentration UNITS  DAILY_AQI_VALUE  \
# 0  01/01/2015                                0.5   ppm                6
# 1  01/02/2015                                0.6   ppm                7
# 2  01/03/2015                                0.8   ppm                9
# 3  01/04/2015                                0.8   ppm                9
# 4  01/05/2015                                1.0   ppm               11
#
#   Site Name   COUNTY
# 0   Oakland  Alameda
# 1   Oakland  Alameda
# 2   Oakland  Alameda
# 3   Oakland  Alameda
# 4   Oakland  Alameda

# %%
#Renaming Columns
CO_2015 = CO_2015.rename(columns={"Site Name": "Site_Name"})
CO_2015 = CO_2015.rename(columns={"Daily Max 8-hour CO Concentration": "Daily_Max_8-hr_CO_Concentration"})
CO_2015.head()
# Out:
#          Date  Daily_Max_8-hr_CO_Concentration UNITS  DAILY_AQI_VALUE  \
# 0  01/01/2015                              0.5   ppm                6
# 1  01/02/2015                              0.6   ppm                7
# 2  01/03/2015                              0.8   ppm                9
# 3  01/04/2015                              0.8   ppm                9
# 4  01/05/2015                              1.0   ppm               11
#
#   Site_Name   COUNTY
# 0   Oakland  Alameda
# 1   Oakland  Alameda
# 2   Oakland  Alameda
# 3   Oakland  Alameda
# 4   Oakland  Alameda

# %%
#Checking Count: 3202
CO_2015.count()
# Out:
# Date                               3202
# Daily_Max_8-hr_CO_Concentration    3202
# UNITS                              3202
# DAILY_AQI_VALUE                    3202
# Site_Name                          3202
# COUNTY                             3202
# dtype: int64

# %%
#Filtering on Site_Name for: Oakland West (OW) & San Francisco (SF)
CO_2015 = CO_2015[(CO_2015.Site_Name == "Oakland West") | (CO_2015.Site_Name == "San Francisco")]
CO_2015.head(600)
# Out:
#             Date  Daily_Max_8-hr_CO_Concentration UNITS  DAILY_AQI_VALUE  \
# 349   01/01/2015                              1.3   ppm               15
# 350   01/02/2015                              1.7   ppm               19
# 351   01/03/2015                              1.8   ppm               20
# 352   01/04/2015                              2.6   ppm               30
# 353   01/05/2015                              1.7   ppm               19
# ...          ...                              ...   ...              ...
# 2728  09/03/2015                              0.3   ppm                3
# 2729  09/04/2015                              0.3   ppm                3
# 2730  09/05/2015                              0.5   ppm                6
# 2731  09/06/2015                              0.6   ppm                7
# 2732  09/07/2015                              0.6   ppm                7
#
#           Site_Name         COUNTY
# 349    Oakland West        Alameda
# ...

# %%
#Checking OW & SF Count: 714
CO_2015.count()
# Out:
# Date                               714
# Daily_Max_8-hr_CO_Concentration    714
# UNITS                              714
# DAILY_AQI_VALUE                    714
# Site_Name                          714
# COUNTY                             714
# dtype: int64

# %%
#Loading raw data CSV: 2015 Nitrogen Dioxide (NO2)
file_to_load = ("2015-no2-sfbay.csv")
NO2_2015 =pd.read_csv(file_to_load)
NO2_2015.head()
# Out:
#          Date Source   Site ID  POC  Daily Max 1-hour NO2 Concentration UNITS  \
# 0  01/01/2015    AQS  60010007    1                                28.0   ppb
# 1  01/02/2015    AQS  60010007    1                                30.0   ppb
# 2  01/03/2015    AQS  60010007    1                                30.9   ppb
# 3  01/04/2015    AQS  60010007    1                                32.7   ppb
# 4  01/05/2015    AQS  60010007    1                                34.6   ppb
#
#    DAILY_AQI_VALUE  Site Name  DAILY_OBS_COUNT  PERCENT_COMPLETE  \
# 0               26  Livermore               23              96.0
# 1               28  Livermore               23              96.0
# 2               28  Livermore               23              96.0
# 3               30  Livermore               23              96.0
# 4               32  Livermore               23              96.0
#
#    AQS_PARAMETER_CODE      AQS_PARAMETER_DESC  CBSA_CODE  \
# ...

# %%
#Checking Columns
NO2_2015.columns
# Out:
# Index(['Date', 'Source', 'Site ID', 'POC',
#        'Daily Max 1-hour NO2 Concentration', 'UNITS', 'DAILY_AQI_VALUE',
#        'Site Name', 'DAILY_OBS_COUNT', 'PERCENT_COMPLETE',
#        'AQS_PARAMETER_CODE', 'AQS_PARAMETER_DESC', 'CBSA_CODE', 'CBSA_NAME',
#        'STATE_CODE', 'STATE', 'COUNTY_CODE', 'COUNTY', 'SITE_LATITUDE',
#        'SITE_LONGITUDE'],
#       dtype='object')

# %%
#Checking Null Values
NO2_2015.columns.isnull()
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False])

# %%
#Dropping Columns
NO2_2015 = NO2_2015.drop(columns=['Source','Site ID','POC','DAILY_OBS_COUNT','PERCENT_COMPLETE','AQS_PARAMETER_CODE','AQS_PARAMETER_DESC', 'CBSA_CODE','CBSA_NAME','STATE_CODE','STATE','COUNTY_CODE','SITE_LATITUDE', 'SITE_LONGITUDE'], axis=1)

# %%
#Checking DataFrame
NO2_2015.head()
# Out:
#            Date  Daily_Max_1-hr_NO2_Concentration UNITS  DAILY_AQI_VALUE  \
# 723  01/01/2015                              39.4   ppb               37
# 724  01/02/2015                              43.9   ppb               41
# 725  01/03/2015                              38.7   ppb               36
# 726  01/04/2015                              44.3   ppb               42
# 727  01/05/2015                              53.1   ppb               50
#
#         Site_Name   COUNTY
# 723  Oakland West  Alameda
# 724  Oakland West  Alameda
# 725  Oakland West  Alameda
# 726  Oakland West  Alameda
# 727  Oakland West  Alameda

# %%
#Renaming Columns
NO2_2015 = NO2_2015.rename(columns={"Site Name": "Site_Name"})
NO2_2015 = NO2_2015.rename(columns={"Daily Max 1-hour NO2 Concentration": "Daily_Max_1-hr_NO2_Concentration"})
NO2_2015.head()
# Out:
#            Date  Daily_Max_1-hr_NO2_Concentration UNITS  DAILY_AQI_VALUE  \
# 723  01/01/2015                              39.4   ppb               37
# 724  01/02/2015                              43.9   ppb               41
# 725  01/03/2015                              38.7   ppb               36
# 726  01/04/2015                              44.3   ppb               42
# 727  01/05/2015                              53.1   ppb               50
#
#         Site_Name   COUNTY
# 723  Oakland West  Alameda
# 724  Oakland West  Alameda
# 725  Oakland West  Alameda
# 726  Oakland West  Alameda
# 727  Oakland West  Alameda

# %%
#Checking Count: 4092
NO2_2015.count()
# Out:
# Date                                721
# Daily_Max_1-hr_NO2_Concentration    721
# UNITS                               721
# DAILY_AQI_VALUE                     721
# Site_Name                           721
# COUNTY                              721
# dtype: int64

# %%
#Filtering on Site_Name for: Oakland West (OW) & San Francisco (SF)
NO2_2015 = NO2_2015[(NO2_2015.Site_Name == "Oakland West") | (NO2_2015.Site_Name == "San Francisco")]
NO2_2015.head(600)
# Out:
#             Date  Daily_Max_1-hr_NO2_Concentration UNITS  DAILY_AQI_VALUE  \
# 723   01/01/2015                              39.4   ppb               37
# 724   01/02/2015                              43.9   ppb               41
# 725   01/03/2015                              38.7   ppb               36
# 726   01/04/2015                              44.3   ppb               42
# 727   01/05/2015                              53.1   ppb               50
# ...          ...                               ...   ...              ...
# 3602  08/26/2015                              13.1   ppb               12
# 3603  08/27/2015                              20.0   ppb               19
# 3604  08/28/2015                              30.3   ppb               28
# 3605  08/29/2015                               8.3   ppb                8
# 3606  08/30/2015                               6.6   ppb                6
#
#           Site_Name         COUNTY
# 723    Oakland West        Alameda
# ...

# %%
#Checking OW & SF Count: 721
NO2_2015.count()
# Out:
# Date                                  721
# Daily Max 1-hour NO2 Concentration    721
# UNITS                                 721
# DAILY_AQI_VALUE                       721
# Site_Name                             721
# COUNTY                                721
# dtype: int64

# %%
#Loading raw data CSV: 2015 Ozone (Oz)
file_to_load = ("2015-oz-sfbay.csv")
Oz_2015 =pd.read_csv(file_to_load)
Oz_2015.head()
# Out:
#          Date Source   Site ID  POC  Daily Max 8-hour Ozone Concentration  \
# 0  01/01/2015    AQS  60010007    1                                 0.025
# 1  01/02/2015    AQS  60010007    1                                 0.027
# 2  01/03/2015    AQS  60010007    1                                 0.021
# 3  01/04/2015    AQS  60010007    1                                 0.027
# 4  01/05/2015    AQS  60010007    1                                 0.030
#
#   UNITS  DAILY_AQI_VALUE  Site Name  DAILY_OBS_COUNT  PERCENT_COMPLETE  \
# 0   ppm               23  Livermore               17             100.0
# 1   ppm               25  Livermore               17             100.0
# 2   ppm               19  Livermore               17             100.0
# 3   ppm               25  Livermore               17             100.0
# 4   ppm               28  Livermore               17             100.0
#
#    AQS_PARAMETER_CODE AQS_PARAMETER_DESC  CBSA_CODE  \
# ...

# %%
#Checking Columns
Oz_2015.columns
# Out:
# Index(['Date', 'Source', 'Site ID', 'POC',
#        'Daily Max 8-hour Ozone Concentration', 'UNITS', 'DAILY_AQI_VALUE',
#        'Site Name', 'DAILY_OBS_COUNT', 'PERCENT_COMPLETE',
#        'AQS_PARAMETER_CODE', 'AQS_PARAMETER_DESC', 'CBSA_CODE', 'CBSA_NAME',
#        'STATE_CODE', 'STATE', 'COUNTY_CODE', 'COUNTY', 'SITE_LATITUDE',
#        'SITE_LONGITUDE'],
#       dtype='object')

# %%
#Checking Null Values
Oz_2015.columns.isnull()
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False])

# %%
#Dropping Columns
Oz_2015 = Oz_2015.drop(columns=['Source','Site ID','POC','DAILY_OBS_COUNT','PERCENT_COMPLETE','AQS_PARAMETER_CODE','AQS_PARAMETER_DESC', 'CBSA_CODE','CBSA_NAME','STATE_CODE','STATE','COUNTY_CODE','SITE_LATITUDE', 'SITE_LONGITUDE'], axis=1)

# %%
#Checking DataFrame
Oz_2015.head()
# Out:
#          Date  Daily Max 8-hour Ozone Concentration UNITS  DAILY_AQI_VALUE  \
# 0  01/01/2015                                 0.025   ppm               23
# 1  01/02/2015                                 0.027   ppm               25
# 2  01/03/2015                                 0.021   ppm               19
# 3  01/04/2015                                 0.027   ppm               25
# 4  01/05/2015                                 0.030   ppm               28
#
#    Site Name   COUNTY
# 0  Livermore  Alameda
# 1  Livermore  Alameda
# 2  Livermore  Alameda
# 3  Livermore  Alameda
# 4  Livermore  Alameda

# %%
#Renaming Columns
Oz_2015 = Oz_2015.rename(columns={"Site Name": "Site_Name"})
Oz_2015 = Oz_2015.rename(columns={"Daily Max 8-hour Ozone Concentration": "Daily_Max_8-hr_Ozone_Concentration"})
Oz_2015.head()
# Out:
#          Date  Daily_Max_8-hr_Ozone_Concentration UNITS  DAILY_AQI_VALUE  \
# 0  01/01/2015                               0.025   ppm               23
# 1  01/02/2015                               0.027   ppm               25
# 2  01/03/2015                               0.021   ppm               19
# 3  01/04/2015                               0.027   ppm               25
# 4  01/05/2015                               0.030   ppm               28
#
#    Site_Name   COUNTY
# 0  Livermore  Alameda
# 1  Livermore  Alameda
# 2  Livermore  Alameda
# 3  Livermore  Alameda
# 4  Livermore  Alameda

# %%
#Checking Count: 3978
Oz_2015.count()
# Out:
# Date                                  3978
# Daily_Max_8-hr_Ozone_Concentration    3978
# UNITS                                 3978
# DAILY_AQI_VALUE                       3978
# Site_Name                             3978
# COUNTY                                3978
# dtype: int64

# %%
#Filtering on Site_Name for: Oakland West (OW) & San Francisco (SF)
Oz_2015 = Oz_2015[(Oz_2015.Site_Name == "Oakland West") | (Oz_2015.Site_Name == "San Francisco")]
Oz_2015.head(600)
# Out:
#             Date  Daily_Max_8-hr_Ozone_Concentration UNITS  DAILY_AQI_VALUE  \
# 715   01/01/2015                               0.034   ppm               31
# 716   01/02/2015                               0.021   ppm               19
# 717   01/03/2015                               0.019   ppm               18
# 718   01/04/2015                               0.021   ppm               19
# 719   01/05/2015                               0.014   ppm               13
# ...          ...                                 ...   ...              ...
# 3499  08/29/2015                               0.026   ppm               24
# 3500  08/30/2015                               0.027   ppm               25
# 3501  08/31/2015                               0.028   ppm               26
# 3502  09/01/2015                               0.029   ppm               27
# 3503  09/02/2015                               0.027   ppm               25
#
#           Site_Name         COUNTY
# ...

# %%
#Checking OW & SF Count: 719
Oz_2015.count()
# Out:
# Date                                  719
# Daily_Max_8-hr_Ozone_Concentration    719
# UNITS                                 719
# DAILY_AQI_VALUE                       719
# Site_Name                             719
# COUNTY                                719
# dtype: int64

# %%
#Loading raw data CSV: 2015 Particulate Matter 2.5 (PM2_5)
file_to_load = ("2015-pm2.5-sfbay.csv")
PM2_5_2015 =pd.read_csv(file_to_load)
PM2_5_2015.head()
# Out:
#          Date Source   Site ID  POC  Daily Mean PM2.5 Concentration     UNITS  \
# 0  01/01/2015    AQS  60010007    3                            16.7  ug/m3 LC
# 1  01/02/2015    AQS  60010007    3                            23.1  ug/m3 LC
# 2  01/03/2015    AQS  60010007    3                            27.5  ug/m3 LC
# 3  01/04/2015    AQS  60010007    3                            28.2  ug/m3 LC
# 4  01/05/2015    AQS  60010007    3                            31.1  ug/m3 LC
#
#    DAILY_AQI_VALUE  Site Name  DAILY_OBS_COUNT  PERCENT_COMPLETE  \
# 0               61  Livermore                1             100.0
# 1               74  Livermore                1             100.0
# 2               83  Livermore                1             100.0
# 3               85  Livermore                1             100.0
# 4               91  Livermore                1             100.0
#
#    AQS_PARAMETER_CODE        AQS_PARAMETER_DESC  CBSA_CODE  \
# ...

# %%
#Checking Columns
PM2_5_2015.columns
# Out:
# Index(['Date', 'Source', 'Site ID', 'POC', 'Daily Mean PM2.5 Concentration',
#        'UNITS', 'DAILY_AQI_VALUE', 'Site Name', 'DAILY_OBS_COUNT',
#        'PERCENT_COMPLETE', 'AQS_PARAMETER_CODE', 'AQS_PARAMETER_DESC',
#        'CBSA_CODE', 'CBSA_NAME', 'STATE_CODE', 'STATE', 'COUNTY_CODE',
#        'COUNTY', 'SITE_LATITUDE', 'SITE_LONGITUDE'],
#       dtype='object')

# %%
#Checking Null Values
PM2_5_2015.columns.isnull()
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False])

# %%
#Dropping Columns
PM2_5_2015 = PM2_5_2015.drop(columns=['Source','Site ID','POC','DAILY_OBS_COUNT','PERCENT_COMPLETE','AQS_PARAMETER_CODE','AQS_PARAMETER_DESC', 'CBSA_CODE','CBSA_NAME','STATE_CODE','STATE','COUNTY_CODE','SITE_LATITUDE', 'SITE_LONGITUDE'], axis=1)

# %%
#Checking DataFrame
PM2_5_2015.head()
# Out:
#          Date  Daily Mean PM2.5 Concentration     UNITS  DAILY_AQI_VALUE  \
# 0  01/01/2015                            16.7  ug/m3 LC               61
# 1  01/02/2015                            23.1  ug/m3 LC               74
# 2  01/03/2015                            27.5  ug/m3 LC               83
# 3  01/04/2015                            28.2  ug/m3 LC               85
# 4  01/05/2015                            31.1  ug/m3 LC               91
#
#    Site Name   COUNTY
# 0  Livermore  Alameda
# 1  Livermore  Alameda
# 2  Livermore  Alameda
# 3  Livermore  Alameda
# 4  Livermore  Alameda

# %%
#Renaming Columns
PM2_5_2015 = PM2_5_2015.rename(columns={"Site Name": "Site_Name"})
PM2_5_2015 = PM2_5_2015.rename(columns={"Daily Mean PM2.5 Concentration": "Daily_Mean_PM2.5_Concentration"})
PM2_5_2015.head()
# Out:
#          Date  Daily_Mean_PM2.5_Concentration     UNITS  DAILY_AQI_VALUE  \
# 0  01/01/2015                            16.7  ug/m3 LC               61
# 1  01/02/2015                            23.1  ug/m3 LC               74
# 2  01/03/2015                            27.5  ug/m3 LC               83
# 3  01/04/2015                            28.2  ug/m3 LC               85
# 4  01/05/2015                            31.1  ug/m3 LC               91
#
#    Site_Name   COUNTY
# 0  Livermore  Alameda
# 1  Livermore  Alameda
# 2  Livermore  Alameda
# 3  Livermore  Alameda
# 4  Livermore  Alameda

# %%
#Checking Count: 
PM2_5_2015.count()
# Out:
# Date                              3254
# Daily_Mean_PM2.5_Concentration    3254
# UNITS                             3254
# DAILY_AQI_VALUE                   3254
# Site_Name                         3254
# COUNTY                            3254
# dtype: int64

# %%
#Filtering on Site_Name for: Oakland West (OW) & San Francisco (SF)
PM2_5_2015 = PM2_5_2015[(PM2_5_2015.Site_Name == "Oakland West") | (PM2_5_2015.Site_Name == "San Francisco")]
PM2_5_2015.head(600)
# Out:
#             Date  Daily_Mean_PM2.5_Concentration     UNITS  DAILY_AQI_VALUE  \
# 717   01/01/2015                            13.0  ug/m3 LC               53
# 718   01/02/2015                            24.0  ug/m3 LC               76
# 719   01/03/2015                            33.7  ug/m3 LC               96
# 720   01/04/2015                            34.8  ug/m3 LC               99
# 721   01/05/2015                            25.8  ug/m3 LC               80
# ...          ...                             ...       ...              ...
# 2790  09/12/2015                             3.9  ug/m3 LC               16
# 2791  09/13/2015                             2.0  ug/m3 LC                8
# 2792  09/14/2015                             1.7  ug/m3 LC                7
# 2793  09/15/2015                             4.2  ug/m3 LC               18
# 2794  09/16/2015                             1.0  ug/m3 LC                4
#
#           Site_Name         COUNTY
# ...

# %%
#Checking OW & SF Count: 699
PM2_5_2015.count()
# Out:
# Date                              699
# Daily_Mean_PM2.5_Concentration    699
# UNITS                             699
# DAILY_AQI_VALUE                   699
# Site_Name                         699
# COUNTY                            699
# dtype: int64

# %%
#Loading raw data CSV: 2015 Particulate Matter 10 (PM10)
file_to_load = ("2015-pm10-sfbay.csv")
PM10_2015 =pd.read_csv(file_to_load)
PM10_2015.head()
# Out:
#          Date Source   Site ID  POC  Daily Mean PM10 Concentration     UNITS  \
# 0  01/06/2015    AQS  60130002    1                             22  ug/m3 SC
# 1  01/18/2015    AQS  60130002    1                             16  ug/m3 SC
# 2  01/30/2015    AQS  60130002    1                             12  ug/m3 SC
# 3  02/11/2015    AQS  60130002    1                              1  ug/m3 SC
# 4  02/23/2015    AQS  60130002    1                             13  ug/m3 SC
#
#    DAILY_AQI_VALUE Site Name  DAILY_OBS_COUNT  PERCENT_COMPLETE  \
# 0               20   Concord                1             100.0
# 1               15   Concord                1             100.0
# 2               11   Concord                1             100.0
# 3                1   Concord                1             100.0
# 4               12   Concord                1             100.0
#
#    AQS_PARAMETER_CODE     AQS_PARAMETER_DESC  CBSA_CODE  \
# 0               81102  PM10 Total 0-10um STP      41860
# ...

# %%
#Checking Columns
PM10_2015.columns
# Out:
# Index(['Date', 'Source', 'Site ID', 'POC', 'Daily Mean PM10 Concentration',
#        'UNITS', 'DAILY_AQI_VALUE', 'Site Name', 'DAILY_OBS_COUNT',
#        'PERCENT_COMPLETE', 'AQS_PARAMETER_CODE', 'AQS_PARAMETER_DESC',
#        'CBSA_CODE', 'CBSA_NAME', 'STATE_CODE', 'STATE', 'COUNTY_CODE',
#        'COUNTY', 'SITE_LATITUDE', 'SITE_LONGITUDE'],
#       dtype='object')

# %%
#Checking Null Values
PM10_2015.columns.isnull()
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False])

# %%
#Dropping Columns
PM10_2015 = PM10_2015.drop(columns=['Source','Site ID','POC','DAILY_OBS_COUNT','PERCENT_COMPLETE','AQS_PARAMETER_CODE','AQS_PARAMETER_DESC', 'CBSA_CODE','CBSA_NAME','STATE_CODE','STATE','COUNTY_CODE','SITE_LATITUDE', 'SITE_LONGITUDE'], axis=1)

# %%
#Checking Columns after drop
PM10_2015.columns
# Out:
# Index(['Date', 'Daily Mean PM10 Concentration', 'UNITS', 'DAILY_AQI_VALUE',
#        'Site Name', 'COUNTY'],
#       dtype='object')

# %%
#Checking DataFrame
PM10_2015.head()
# Out:
#          Date  Daily Mean PM10 Concentration     UNITS  DAILY_AQI_VALUE  \
# 0  01/06/2015                             22  ug/m3 SC               20
# 1  01/18/2015                             16  ug/m3 SC               15
# 2  01/30/2015                             12  ug/m3 SC               11
# 3  02/11/2015                              1  ug/m3 SC                1
# 4  02/23/2015                             13  ug/m3 SC               12
#
#   Site Name        COUNTY
# 0   Concord  Contra Costa
# 1   Concord  Contra Costa
# 2   Concord  Contra Costa
# 3   Concord  Contra Costa
# 4   Concord  Contra Costa

# %%
#Renaming Columns
PM10_2015 = PM10_2015.rename(columns={"Site Name": "Site_Name"})
PM10_2015 = PM10_2015.rename(columns={"Daily Mean PM10 Concentration": "Daily_Mean_PM10_Concentration"})
PM10_2015.head()
# Out:
#          Date  Daily_Mean_PM10_Concentration     UNITS  DAILY_AQI_VALUE  \
# 0  01/06/2015                             22  ug/m3 SC               20
# 1  01/18/2015                             16  ug/m3 SC               15
# 2  01/30/2015                             12  ug/m3 SC               11
# 3  02/11/2015                              1  ug/m3 SC                1
# 4  02/23/2015                             13  ug/m3 SC               12
#
#   Site_Name        COUNTY
# 0   Concord  Contra Costa
# 1   Concord  Contra Costa
# 2   Concord  Contra Costa
# 3   Concord  Contra Costa
# 4   Concord  Contra Costa

# %%
#Checking Count: 
PM10_2015.count()
# Out:
# Date                             208
# Daily_Mean_PM10_Concentration    208
# UNITS                            208
# DAILY_AQI_VALUE                  208
# Site_Name                        208
# COUNTY                           208
# dtype: int64

# %%
#Filtering on Site_Name for: Oakland West (OW) & San Francisco (SF)
PM10_2015 = PM10_2015[(PM10_2015.Site_Name == "Oakland West") | (PM10_2015.Site_Name == "San Francisco")]
PM10_2015.head()
#Note: Oakland West has no PM10 data
# Out:
#            Date  Daily_Mean_PM10_Concentration     UNITS  DAILY_AQI_VALUE  \
# 178  01/06/2015                             44  ug/m3 SC               41
# 179  01/18/2015                             18  ug/m3 SC               17
# 180  01/30/2015                             24  ug/m3 SC               22
# 181  02/11/2015                             16  ug/m3 SC               15
# 182  02/23/2015                             20  ug/m3 SC               19
#
#          Site_Name         COUNTY
# 178  San Francisco  San Francisco
# 179  San Francisco  San Francisco
# 180  San Francisco  San Francisco
# 181  San Francisco  San Francisco
# 182  San Francisco  San Francisco

# %%
#Checking OW & SF Count: 
PM10_2015.count()
# Out:
# Date                             30
# Daily_Mean_PM10_Concentration    30
# UNITS                            30
# DAILY_AQI_VALUE                  30
# Site_Name                        30
# COUNTY                           30
# dtype: int64

# %%
#Loading raw data CSV: 2015 Sulfur Dioxide (SO2)
file_to_load = ("2015-so2-sfbay.csv")
SO2_2015 =pd.read_csv(file_to_load)
SO2_2015.head()
# Out:
#          Date Source   Site ID  POC  Daily Max 1-hour SO2 Concentration UNITS  \
# 0  01/01/2015    AQS  60010011    1                                 1.5   ppb
# 1  01/02/2015    AQS  60010011    1                                 5.6   ppb
# 2  01/03/2015    AQS  60010011    1                                 3.7   ppb
# 3  01/04/2015    AQS  60010011    1                                 2.1   ppb
# 4  01/05/2015    AQS  60010011    1                                 4.6   ppb
#
#    DAILY_AQI_VALUE     Site Name  DAILY_OBS_COUNT  PERCENT_COMPLETE  \
# 0                1  Oakland West               22              92.0
# 1                7  Oakland West               22              92.0
# 2                4  Oakland West               22              92.0
# 3                3  Oakland West               22              92.0
# 4                6  Oakland West               22              92.0
#
#    AQS_PARAMETER_CODE AQS_PARAMETER_DESC  CBSA_CODE  \
# ...

# %%
#Checking Columns
SO2_2015.columns
# Out:
# Index(['Date', 'Source', 'Site ID', 'POC',
#        'Daily Max 1-hour SO2 Concentration', 'UNITS', 'DAILY_AQI_VALUE',
#        'Site Name', 'DAILY_OBS_COUNT', 'PERCENT_COMPLETE',
#        'AQS_PARAMETER_CODE', 'AQS_PARAMETER_DESC', 'CBSA_CODE', 'CBSA_NAME',
#        'STATE_CODE', 'STATE', 'COUNTY_CODE', 'COUNTY', 'SITE_LATITUDE',
#        'SITE_LONGITUDE'],
#       dtype='object')

# %%
#Checking Null Values
SO2_2015.columns.isnull()
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False])

# %%
#Dropping Columns
SO2_2015 = SO2_2015.drop(columns=['Source','Site ID','POC','DAILY_OBS_COUNT','PERCENT_COMPLETE','AQS_PARAMETER_CODE','AQS_PARAMETER_DESC', 'CBSA_CODE','CBSA_NAME','STATE_CODE','STATE','COUNTY_CODE','SITE_LATITUDE', 'SITE_LONGITUDE'], axis=1)

# %%
#Checking Columns after drop
SO2_2015.columns
# Out:
# Index(['Date', 'Daily Max 1-hour SO2 Concentration', 'UNITS',
#        'DAILY_AQI_VALUE', 'Site Name', 'COUNTY'],
#       dtype='object')

# %%
#Checking DataFrame
SO2_2015.head()
# Out:
#          Date  Daily Max 1-hour SO2 Concentration UNITS  DAILY_AQI_VALUE  \
# 0  01/01/2015                                 1.5   ppb                1
# 1  01/02/2015                                 5.6   ppb                7
# 2  01/03/2015                                 3.7   ppb                4
# 3  01/04/2015                                 2.1   ppb                3
# 4  01/05/2015                                 4.6   ppb                6
#
#       Site Name   COUNTY
# 0  Oakland West  Alameda
# 1  Oakland West  Alameda
# 2  Oakland West  Alameda
# 3  Oakland West  Alameda
# 4  Oakland West  Alameda

# %%
#Renaming Columns
SO2_2015 = SO2_2015.rename(columns={"Site Name": "Site_Name"})
SO2_2015 = SO2_2015.rename(columns={"Daily Max 1-hour SO2 Concentration": "Daily_Max_1-hr_SO2_Concentration"})
SO2_2015.head()
# Out:
#          Date  Daily_Max_1-hour_SO2_Concentration UNITS  DAILY_AQI_VALUE  \
# 0  01/01/2015                                 1.5   ppb                1
# 1  01/02/2015                                 5.6   ppb                7
# 2  01/03/2015                                 3.7   ppb                4
# 3  01/04/2015                                 2.1   ppb                3
# 4  01/05/2015                                 4.6   ppb                6
#
#       Site_Name   COUNTY
# 0  Oakland West  Alameda
# 1  Oakland West  Alameda
# 2  Oakland West  Alameda
# 3  Oakland West  Alameda
# 4  Oakland West  Alameda

# %%
#Checking Count: 
SO2_2015.count()
# Out:
# Date                                  2503
# Daily_Max_1-hour_SO2_Concentration    2503
# UNITS                                 2503
# DAILY_AQI_VALUE                       2503
# Site_Name                             2503
# COUNTY                                2503
# dtype: int64

# %%
#Filtering on Site_Name for: Oakland West (OW) & San Francisco (SF)
SO2_2015 = SO2_2015[(SO2_2015.Site_Name == "Oakland West") | (SO2_2015.Site_Name == "San Francisco")]
SO2_2015.head()
#Note: San Francisco has no SO2 data
# Out:
#          Date  Daily_Max_1-hour_SO2_Concentration UNITS  DAILY_AQI_VALUE  \
# 0  01/01/2015                                 1.5   ppb                1
# 1  01/02/2015                                 5.6   ppb                7
# 2  01/03/2015                                 3.7   ppb                4
# 3  01/04/2015                                 2.1   ppb                3
# 4  01/05/2015                                 4.6   ppb                6
#
#       Site_Name   COUNTY
# 0  Oakland West  Alameda
# 1  Oakland West  Alameda
# 2  Oakland West  Alameda
# 3  Oakland West  Alameda
# 4  Oakland West  Alameda

# %%
#Checking OW & SF Count: 359
SO2_2015.count()
# Out:
# Date                                  359
# Daily_Max_1-hour_SO2_Concentration    359
# UNITS                                 359
# DAILY_AQI_VALUE                       359
# Site_Name                             359
# COUNTY                                359
# dtype: int64
